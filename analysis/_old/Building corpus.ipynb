# %% [markdown]
# # Define functions

# %%
#additional functions
def strip(word):
    mod_string = re.sub(r'\W+', '', word)
    return mod_string

#the following leaves in place two or more capital letters in a row
#will be ignored when using standard stemming
def abbr_or_lower(word):
    if re.match('([A-Z]+[a-z]*){2,}', word):
        return word
    else:
        return word.lower()

#modular pipeline for stemming, lemmatizing and lowercasing
#note this is NOT lemmatizing using grammar pos
    
def tokenize(text, modulation):
    if modulation<2:
        tokens = re.split(r'\W+', text)
        stems = []
        # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
        for token in tokens:
            lowers=abbr_or_lower(token)
            if lowers not in stop_words:
                if re.search('[a-zA-Z]', lowers):
                    if modulation==0:
                        stems.append(lowers)
                    if modulation==1:
                        stems.append(porter.stem(lowers))
    else:
        sp_text=sp(text)
        stems = []
        lemmatized_text=[]
        for word in sp_text:
            lemmatized_text.append(word.lemma_)
        stems = [abbr_or_lower(strip(w)) for w in lemmatized_text if (abbr_or_lower(strip(w))) and (abbr_or_lower(strip(w)) not in stop_words)]
    return " ".join(stems)


def vectorize(tokens, vocab):
    vector=[]
    for w in vocab:
        vector.append(tokens.count(w))
    return vector

# %%
# Define pre posessing pipleines
def preprocess_text_data(corpus_data, mod, column):

    text_preproc = corpus_data[column].astype(str).progress_apply(lambda row: tokenize(row, mod))
    
    corpus_data[column] = text_preproc

    corpus_data.dropna(subset=[column], inplace=True)
    corpus_data.reset_index(drop=True, inplace=True)
    
    # Convert to string
    corpus_data[column] = corpus_data[column].astype(str)

    return corpus_data

# %% [markdown]
# # Load data

# %%
import pandas as pd
import re
from tqdm import tqdm
tqdm.pandas()
import numpy as np
from matplotlib import pyplot as plt

from nltk.stem import WordNetLemmatizer
from nltk.stem import SnowballStemmer 
from nltk.corpus import stopwords

import spacy
sp = spacy.load('en_core_web_sm')

from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer

# %%
#getting a library of stopwords and defining a lemmatizer
porter=SnowballStemmer("english")
lmtzr = WordNetLemmatizer()

stop_words = set(stopwords.words('english'))

# %%
lyrics_df = pd.read_csv('../../data/top songs.csv')

# %%
lyrics_df
# Out:
#                                title   tag                        artist  \
# 0                          let it be  rock                   the beatles
# 1                          your song  rock                    elton john
# 2                           paranoid  rock                 black sabbath
# 3                     immigrant song  rock                  led zeppelin
# 4        have you ever seen the rain  rock  creedence clearwater revival
# ...                              ...   ...                           ...
# 191995  attention female perspective   pop                    andie case
# 191996                     ​nobody 😔   rap                     shinigami
# 191997                       my time   rap                        wolves
# 191998                down in flames   pop                      ella vos
# 191999                       blank 2   rap              jeffy the puppet
#
#         release year    views      features  \
# 0               1970  1481859            {}
# 1               1970  1323166            {}
# 2               1970   508767            {}
# 3               1970   494355            {}
# 4               1970   468949            {}
# ...              ...      ...           ...
# 191995          2017    34129            {}
# 191996          2017    34115  {​shinigami}
# 191997          2017    34114            {}
# 191998          2017    34113            {}
# 191999          2017    34102            {}
#
#                                                    lyrics
# 0        When I find myself in times of trouble, Mothe...
# 1        It's a little bit funny, this feeling inside ...
# 2          Finished with my woman 'Cause she couldn't ...
# 3       ​ (2, 3, 4)   Ahh! Ahh! We come from the land ...
# 4        Someone told me long ago There's a calm befor...
# ...                                                   ...
# 191995   I been runnin' 'round, runnin' 'round, runnin...
# 191996   Take me away from this path that I follow It'...
# 191997  I'm ready to play now Put me in the game now I...
# 191998   Slippin' off the edge Out of phase Watchin' y...
# 191999  Jeffy, The Puppet: Hey daddy, I smack these Ho...
#
# [192000 rows x 7 columns]

# %% [markdown]
# # Clean song lyrics

# %%
# Remove text inside square brackets
lyrics_df['lyrics'] = lyrics_df['lyrics'].str.replace(r'\[.*?\]', '', regex=True)

# Replace \n with a space 
lyrics_df['lyrics'] = lyrics_df['lyrics'].str.replace('\n', ' ', regex=False)

# %%
lyrics_df = preprocess_text_data(lyrics_df, mod = 2, column = 'lyrics')

# %%
lyrics_df = lyrics_df.dropna(subset=['lyrics'])
lyrics_df.to_csv('../../data/top songs processed.csv', index=False)

# %%
lyrics_df = pd.read_csv('../../data/top songs processed.csv')

# %% [markdown]
# # Futher processing

# %%
cv = CountVectorizer(ngram_range = (1,2), lowercase=True, min_df=0.01, max_df=0.99, stop_words='english')

cv.fit(lyrics_df.lyrics)
vectorized_text=cv.transform(lyrics_df.lyrics)
vectorized_text=vectorized_text.todense()
print("document term matrix has size", vectorized_text.shape)
# Out:
# document term matrix has size (191999, 1340)

# %%
term_frequencies = np.sum(vectorized_text, axis=0).A1

# Sort frequencies and get sorted indices
sorted_indices = np.argsort(term_frequencies)[::-1]
sorted_frequencies = term_frequencies[list(sorted_indices)]

# Generate Term IDs (1-based indexing for better readability)
term_ids = np.arange(1, len(sorted_frequencies) + 1)

# Find the maximum value in the sorted frequencies
max_term_frequency = np.max(sorted_frequencies)
print("Max term frequency is", max_term_frequency)

# Get the feature names from the count vectorizer
feature_names = cv.get_feature_names_out()

# Now use sorted_indices to get the top terms
top_indices = sorted_indices[:5]  # Get the indices for the top 5 terms
top_terms = feature_names[top_indices]  # Get the corresponding feature names

# Now print out the top terms with their frequencies
for term, freq in zip(top_terms, sorted_frequencies[:5]):
    print(f"Term: {term}, Frequency: {freq}")
# Out:
# Max term frequency is 400851
# Term: like, Frequency: 400851
# Term: know, Frequency: 398182
# Term: love, Frequency: 357946
# Term: oh, Frequency: 274673
# Term: say, Frequency: 264440

# %%
# Plotting with adjusted y-axis limits
plt.figure(figsize=(12, 6))
plt.bar(term_ids, sorted_frequencies, width=1.0, edgecolor='black')

# Set the y-axis and x-axis limits to start at 0 and end at the maximum
plt.ylim(0, max_term_frequency)
plt.xlim(left=0, right=len(term_ids)+1) 

# Improve the appearance
plt.title('Term Frequency Distribution')
plt.xlabel('Term ID')
plt.ylabel('Term Frequency')
plt.grid(True, which="both", ls="--", linewidth=0.5)

plt.axhline(y=0, color='black', linewidth=1)

plt.show()

# %%
from sklearn.feature_extraction.text import TfidfTransformer

# Create the TfidfTransformer instance
tfidf_transformer = TfidfTransformer()

# Assuming 'vectorized_text' is the sparse matrix obtained from CountVectorizer
# Fit and transform the vectorized text data to get the TF-IDF representation
vectorized_text = np.asarray(vectorized_text)
tfidf_matrix = tfidf_transformer.fit_transform(vectorized_text)

# Now convert the sparse TF-IDF matrix to a dense numpy array
tfidf_matrix_dense = tfidf_matrix.toarray()

# Show the shape of the TF-IDF matrix
print("TF-IDF matrix has size", tfidf_matrix_dense.shape)
# Out:
# TF-IDF matrix has size (191999, 1340)

# %%
# Now you can see the words that match to each column
for i, feature in enumerate(feature_names):
    print(f"Column {i}: {feature}")
# Out:
# Column 0: 10
# Column 1: 20
# Column 2: 40
# Column 3: 50
# Column 4: act
# Column 5: act like
# Column 6: actin
# Column 7: action
# Column 8: add
# Column 9: admit
# Column 10: afraid
# Column 11: age
# Column 12: ago
# Column 13: ah
# Column 14: ahead
# Column 15: ai
# Column 16: aim
# Column 17: air
# Column 18: album
# Column 19: alive
# Column 20: alright
# Column 21: america
# Column 22: angel
# Column 23: animal
# Column 24: answer
# Column 25: anybody
# Column 26: anymore
# Column 27: apart
# Column 28: appear
# Column 29: arm
# Column 30: army
# Column 31: art
# Column 32: ask
# Column 33: asleep
# Column 34: ass
# Column 35: attack
# Column 36: attention
# Column 37: awake
# Column 38: away
# Column 39: ay
# Column 40: ayy
# Column 41: babe
# Column 42: baby
# Column 43: baby baby
# Column 44: baby come
# Column 45: baby girl
# Column 46: baby know
# Column 47: baby let
# Column 48: baby love
# Column 49: baby oh
# Column 50: bad
# Column 51: bag
# Column 52: ball
# Column 53: band
# Column 54: bang
# Column 55: bank
# Column 56: bar
# Column 57: barely
# Column 58: bass
# Column 59: battle
# Column 60: beach
# Column 61: bear
# Column 62: beast
# Column 63: beat
# Column 64: beautiful
# Column 65: beauty
# Column 66: bed
# Column 67: beef
# Column 68: beer
# Column 69: beg
# Column 70: begin
# Column 71: believe
# Column 72: bell
# Column 73: belong
# Column 74: bend
# Column 75: beneath
# Column 76: benz
# Column 77: bet
# Column 78: big
# Column 79: bind
# Column 80: bird
# Column 81: bit
# Column 82: bitch
# Column 83: bite
# Column 84: black
# Column 85: blame
# Column 86: blast
# Column 87: blaze
# Column 88: bleed
# Column 89: bless
# Column 90: blind
# Column 91: block
# Column 92: blood
# Column 93: bloody
# Column 94: blow
# Column 95: blowin
# Column 96: blue
# Column 97: blunt
# Column 98: boat
# Column 99: body
# Column 100: bomb
# Column 101: bone
# Column 102: boo
# Column 103: book
# Column 104: boom
# Column 105: boot
# Column 106: boss
# Column 107: bother
# Column 108: bottle
# Column 109: bounce
# Column 110: bout
# Column 111: bow
# Column 112: box
# Column 113: boy
# Column 114: brain
# Column 115: brand
# Column 116: brand new
# Column 117: bread
# Column 118: break
# Column 119: break heart
# Column 120: breath
# Column 121: breathe
# Column 122: breeze
# Column 123: brick
# Column 124: bridge
# Column 125: bright
# Column 126: bring
# Column 127: broad
# Column 128: broken
# Column 129: brother
# Column 130: brown
# Column 131: buck
# Column 132: build
# Column 133: building
# Column 134: bullet
# Column 135: bullshit
# Column 136: bump
# Column 137: bunch
# Column 138: burn
# Column 139: bury
# Column 140: bus
# Column 141: business
# Column 142: bust
# Column 143: busy
# Column 144: butt
# Column 145: buy
# Column 146: bye
# Column 147: cake
# Column 148: callin
# Column 149: calm
# Column 150: candle
# Column 151: candy
# Column 152: cap
# Column 153: car
# Column 154: card
# Column 155: care
# Column 156: carry
# Column 157: case
# Column 158: cash
# Column 159: cast
# Column 160: cat
# Column 161: catch
# Column 162: cause
# Column 163: cause know
# Column 164: cause love
# Column 165: cell
# Column 166: certain
# Column 167: chain
# Column 168: chair
# Column 169: chance
# Column 170: change
# Column 171: charge
# Column 172: chase
# Column 173: cheap
# Column 174: check
# Column 175: cheese
# Column 176: chest
# Column 177: chick
# Column 178: chicken
# Column 179: child
# Column 180: chill
# Column 181: chip
# Column 182: choice
# Column 183: choke
# Column 184: choose
# Column 185: chop
# Column 186: chorus
# Column 187: christ
# Column 188: christmas
# Column 189: church
# Column 190: cigarette
# Column 191: circle
# Column 192: city
# Column 193: claim
# Column 194: clap
# Column 195: class
# Column 196: clean
# Column 197: clear
# Column 198: click
# Column 199: climb
# Column 200: clip
# Column 201: clock
# Column 202: close
# Column 203: close eye
# Column 204: clothe
# Column 205: cloud
# Column 206: clown
# Column 207: club
# Column 208: coast
# Column 209: coat
# Column 210: cock
# Column 211: coke
# Column 212: cold
# Column 213: color
# Column 214: come
# Column 215: come baby
# Column 216: come come
# Column 217: come home
# Column 218: come know
# Column 219: come let
# Column 220: come like
# Column 221: come true
# Column 222: comin
# Column 223: company
# Column 224: complete
# Column 225: control
# Column 226: conversation
# Column 227: cook
# Column 228: cool
# Column 229: cop
# Column 230: corner
# Column 231: cos
# Column 232: cost
# Column 233: count
# Column 234: country
# Column 235: couple
# Column 236: course
# Column 237: court
# Column 238: cover
# Column 239: crack
# Column 240: crash
# Column 241: crawl
# Column 242: crazy
# Column 243: cream
# Column 244: create
# Column 245: creep
# Column 246: crew
# Column 247: crib
# Column 248: crime
# Column 249: cross
# Column 250: crowd
# Column 251: crown
# Column 252: crush
# Column 253: cup
# Column 254: curse
# Column 255: cut
# Column 256: cuz
# Column 257: da
# Column 258: dad
# Column 259: daddy
# Column 260: damn
# Column 261: dance
# Column 262: danger
# Column 263: dare
# Column 264: dark
# Column 265: darkness
# Column 266: darling
# Column 267: date
# Column 268: daughter
# Column 269: dawn
# Column 270: day
# Column 271: day day
# Column 272: day night
# Column 273: dead
# Column 274: deal
# Column 275: dear
# Column 276: death
# Column 277: decide
# Column 278: deep
# Column 279: deep inside
# Column 280: demon
# Column 281: deny
# Column 282: desert
# Column 283: deserve
# Column 284: desire
# Column 285: destiny
# Column 286: destroy
# Column 287: devil
# Column 288: diamond
# Column 289: dick
# Column 290: die
# Column 291: difference
# Column 292: different
# Column 293: dig
# Column 294: dime
# Column 295: dinner
# Column 296: dip
# Column 297: direction
# Column 298: dirt
# Column 299: dirty
# Column 300: disappear
# Column 301: distance
# Column 302: dj
# Column 303: doctor
# Column 304: dog
# Column 305: dollar
# Column 306: door
# Column 307: dope
# Column 308: double
# Column 309: doubt
# Column 310: dough
# Column 311: drag
# Column 312: drama
# Column 313: draw
# Column 314: dream
# Column 315: dress
# Column 316: drift
# Column 317: drink
# Column 318: drive
# Column 319: drop
# Column 320: drown
# Column 321: drug
# Column 322: drum
# Column 323: drunk
# Column 324: dry
# Column 325: duck
# Column 326: dude
# Column 327: dumb
# Column 328: dust
# Column 329: ear
# Column 330: early
# Column 331: earth
# Column 332: ease
# Column 333: east
# Column 334: easy
# Column 335: eat
# Column 336: edge
# Column 337: em
# Column 338: emotion
# Column 339: end
# Column 340: enemy
# Column 341: enter
# Column 342: escape
# Column 343: evening
# Column 344: everybody
# Column 345: everyday
# Column 346: evil
# Column 347: exactly
# Column 348: excuse
# Column 349: exist
# Column 350: expect
# Column 351: explain
# Column 352: eye
# Column 353: face
# Column 354: fact
# Column 355: fade
# Column 356: fail
# Column 357: fair
# Column 358: faith
# Column 359: fake
# Column 360: fall
# Column 361: fall love
# Column 362: fame
# Column 363: family
# Column 364: fan
# Column 365: fantasy
# Column 366: far
# Column 367: far away
# Column 368: fast
# Column 369: fat
# Column 370: fate
# Column 371: father
# Column 372: favorite
# Column 373: fear
# Column 374: feed
# Column 375: feel
# Column 376: feel feel
# Column 377: feel good
# Column 378: feel like
# Column 379: feel way
# Column 380: feelin
# Column 381: feeling
# Column 382: field
# Column 383: fiend
# Column 384: fight
# Column 385: figure
# Column 386: final
# Column 387: finally
# Column 388: fine
# Column 389: finger
# Column 390: finish
# Column 391: fish
# Column 392: fist
# Column 393: fit
# Column 394: fix
# Column 395: flame
# Column 396: flash
# Column 397: flat
# Column 398: flesh
# Column 399: flight
# Column 400: flip
# Column 401: float
# Column 402: floor
# Column 403: flow
# Column 404: flower
# Column 405: fly
# Column 406: focus
# Column 407: folk
# Column 408: follow
# Column 409: food
# Column 410: fool
# Column 411: foot
# Column 412: force
# Column 413: forever
# Column 414: forget
# Column 415: forgive
# Column 416: form
# Column 417: frame
# Column 418: freak
# Column 419: free
# Column 420: freedom
# Column 421: freeze
# Column 422: fresh
# Column 423: friend
# Column 424: fuck
# Column 425: fuckin
# Column 426: fucking
# Column 427: fun
# Column 428: funky
# Column 429: funny
# Column 430: future
# Column 431: gain
# Column 432: game
# Column 433: gang
# Column 434: gangsta
# Column 435: garden
# Column 436: gas
# Column 437: gat
# Column 438: gate
# Column 439: gather
# Column 440: gettin
# Column 441: getting
# Column 442: ghetto
# Column 443: ghost
# Column 444: gift
# Column 445: gimme
# Column 446: girl
# Column 447: girl know
# Column 448: girlfriend
# Column 449: givin
# Column 450: glad
# Column 451: glass
# Column 452: glock
# Column 453: glory
# Column 454: glow
# Column 455: god
# Column 456: goin
# Column 457: gold
# Column 458: golden
# Column 459: gon
# Column 460: good
# Column 461: good friend
# Column 462: good thing
# Column 463: good time
# Column 464: goodbye
# Column 465: got
# Column 466: grab
# Column 467: grace
# Column 468: grand
# Column 469: grass
# Column 470: grave
# Column 471: great
# Column 472: green
# Column 473: grey
# Column 474: grind
# Column 475: grip
# Column 476: groove
# Column 477: ground
# Column 478: grow
# Column 479: guess
# Column 480: guide
# Column 481: guitar
# Column 482: gun
# Column 483: guy
# Column 484: ha
# Column 485: ha ha
# Column 486: haha
# Column 487: hair
# Column 488: half
# Column 489: hall
# Column 490: hand
# Column 491: handle
# Column 492: hang
# Column 493: happen
# Column 494: happiness
# Column 495: happy
# Column 496: hard
# Column 497: hat
# Column 498: hate
# Column 499: hater
# Column 500: head
# Column 501: heal
# Column 502: hear
# Column 503: hear say
# Column 504: heart
# Column 505: heat
# Column 506: heaven
# Column 507: heavy
# Column 508: hell
# Column 509: hello
# Column 510: help
# Column 511: hero
# Column 512: hey
# Column 513: hey hey
# Column 514: hi
# Column 515: hide
# Column 516: high
# Column 517: highway
# Column 518: hill
# Column 519: hip
# Column 520: hip hop
# Column 521: history
# Column 522: hit
# Column 523: ho
# Column 524: hoe
# Column 525: hold
# Column 526: hold hand
# Column 527: hold tight
# Column 528: holdin
# Column 529: hole
# Column 530: holy
# Column 531: home
# Column 532: homie
# Column 533: honey
# Column 534: hood
# Column 535: hook
# Column 536: hop
# Column 537: hope
# Column 538: horse
# Column 539: hot
# Column 540: hotel
# Column 541: hour
# Column 542: house
# Column 543: huh
# Column 544: human
# Column 545: hungry
# Column 546: hurry
# Column 547: hurt
# Column 548: hustle
# Column 549: ice
# Column 550: idea
# Column 551: ignore
# Column 552: ill
# Column 553: imagine
# Column 554: imma
# Column 555: insane
# Column 556: inside
# Column 557: instead
# Column 558: island
# Column 559: jack
# Column 560: jail
# Column 561: jam
# Column 562: jean
# Column 563: jesus
# Column 564: jet
# Column 565: job
# Column 566: john
# Column 567: join
# Column 568: joke
# Column 569: joy
# Column 570: judge
# Column 571: juice
# Column 572: jump
# Column 573: key
# Column 574: kick
# Column 575: kid
# Column 576: kill
# Column 577: killer
# Column 578: killin
# Column 579: kind
# Column 580: kinda
# Column 581: king
# Column 582: kiss
# Column 583: kitchen
# Column 584: knee
# Column 585: knife
# Column 586: knock
# Column 587: know
# Column 588: know cause
# Column 589: know come
# Column 590: know feel
# Column 591: know good
# Column 592: know know
# Column 593: know like
# Column 594: know love
# Column 595: know make
# Column 596: know mean
# Column 597: know need
# Column 598: know right
# Column 599: know say
# Column 600: know tell
# Column 601: know think
# Column 602: know time
# Column 603: know want
# Column 604: know way
# Column 605: la
# Column 606: la la
# Column 607: label
# Column 608: lady
# Column 609: lame
# Column 610: land
# Column 611: lane
# Column 612: late
# Column 613: late night
# Column 614: lately
# Column 615: later
# Column 616: laugh
# Column 617: laughter
# Column 618: law
# Column 619: lay
# Column 620: lead
# Column 621: lean
# Column 622: learn
# Column 623: leather
# Column 624: leave
# Column 625: leavin
# Column 626: left
# Column 627: leg
# Column 628: lesson
# Column 629: let
# Column 630: let know
# Column 631: let let
# Column 632: let tell
# Column 633: letter
# Column 634: level
# Column 635: lick
# Column 636: lie
# Column 637: life
# Column 638: lift
# Column 639: light
# Column 640: like
# Column 641: like know
# Column 642: like like
# Column 643: like love
# Column 644: like say
# Column 645: lil
# Column 646: line
# Column 647: lip
# Column 648: liquor
# Column 649: list
# Column 650: listen
# Column 651: little
# Column 652: little bit
# Column 653: little girl
# Column 654: live
# Column 655: live life
# Column 656: livin
# Column 657: living
# Column 658: load
# Column 659: lock
# Column 660: lonely
# Column 661: long
# Column 662: long time
# Column 663: look
# Column 664: look eye
# Column 665: look good
# Column 666: look like
# Column 667: lookin
# Column 668: loose
# Column 669: lord
# Column 670: lose
# Column 671: lot
# Column 672: loud
# Column 673: love
# Column 674: love baby
# Column 675: love come
# Column 676: love know
# Column 677: love like
# Column 678: love love
# Column 679: love make
# Column 680: love oh
# Column 681: love say
# Column 682: love want
# Column 683: love way
# Column 684: lovely
# Column 685: lover
# Column 686: lovin
# Column 687: low
# Column 688: luck
# Column 689: lucky
# Column 690: lyric
# Column 691: machine
# Column 692: mad
# Column 693: magic
# Column 694: main
# Column 695: make
# Column 696: make feel
# Column 697: make love
# Column 698: make sure
# Column 699: makin
# Column 700: mama
# Column 701: man
# Column 702: man know
# Column 703: mark
# Column 704: marry
# Column 705: mask
# Column 706: master
# Column 707: match
# Column 708: matter
# Column 709: maybe
# Column 710: mc
# Column 711: mean
# Column 712: meet
# Column 713: melt
# Column 714: memory
# Column 715: mention
# Column 716: mercy
# Column 717: mess
# Column 718: message
# Column 719: mic
# Column 720: middle
# Column 721: midnight
# Column 722: mighty
# Column 723: mile
# Column 724: million
# Column 725: mind
# Column 726: minute
# Column 727: mirror
# Column 728: miss
# Column 729: mission
# Column 730: mistake
# Column 731: mix
# Column 732: mmm
# Column 733: mo
# Column 734: mom
# Column 735: moment
# Column 736: momma
# Column 737: money
# Column 738: month
# Column 739: moon
# Column 740: morning
# Column 741: mother
# Column 742: motherfucke
# Column 743: motherfucker
# Column 744: motherfuckin
# Column 745: motion
# Column 746: mountain
# Column 747: mouth
# Column 748: movie
# Column 749: movin
# Column 750: mr
# Column 751: murder
# Column 752: music
# Column 753: mystery
# Column 754: nah
# Column 755: nail
# Column 756: naked
# Column 757: nasty
# Column 758: nation
# Column 759: nature
# Column 760: near
# Column 761: neck
# Column 762: need
# Column 763: need know
# Column 764: need love
# Column 765: need need
# Column 766: new
# Column 767: new york
# Column 768: news
# Column 769: nice
# Column 770: nigga
# Column 771: niggas
# Column 772: niggas know
# Column 773: night
# Column 774: night long
# Column 775: noise
# Column 776: north
# Column 777: nose
# Column 778: note
# Column 779: notice
# Column 780: number
# Column 781: nut
# Column 782: ocean
# Column 783: offer
# Column 784: oh
# Column 785: oh baby
# Column 786: oh god
# Column 787: oh know
# Column 788: oh love
# Column 789: oh oh
# Column 790: oh yeah
# Column 791: ohh
# Column 792: ok
# Column 793: okay
# Column 794: old
# Column 795: ooh
# Column 796: ooh ooh
# Column 797: oooh
# Column 798: open
# Column 799: open eye
# Column 800: order
# Column 801: outside
# Column 802: outta
# Column 803: pack
# Column 804: page
# Column 805: pain
# Column 806: paint
# Column 807: pair
# Column 808: pant
# Column 809: paper
# Column 810: park
# Column 811: party
# Column 812: pass
# Column 813: passion
# Column 814: past
# Column 815: path
# Column 816: pay
# Column 817: peace
# Column 818: peep
# Column 819: pen
# Column 820: people
# Column 821: perfect
# Column 822: person
# Column 823: phone
# Column 824: pick
# Column 825: picture
# Column 826: piece
# Column 827: pill
# Column 828: pimp
# Column 829: pipe
# Column 830: piss
# Column 831: pistol
# Column 832: place
# Column 833: plain
# Column 834: plan
# Column 835: plane
# Column 836: planet
# Column 837: plate
# Column 838: play
# Column 839: play game
# Column 840: player
# Column 841: playin
# Column 842: pleasure
# Column 843: plenty
# Column 844: plus
# Column 845: pocket
# Column 846: point
# Column 847: poison
# Column 848: police
# Column 849: pool
# Column 850: poor
# Column 851: pop
# Column 852: poppin
# Column 853: position
# Column 854: post
# Column 855: pot
# Column 856: pound
# Column 857: pour
# Column 858: power
# Column 859: praise
# Column 860: pray
# Column 861: prayer
# Column 862: press
# Column 863: pressure
# Column 864: pretend
# Column 865: pretty
# Column 866: price
# Column 867: pride
# Column 868: prison
# Column 869: probably
# Column 870: problem
# Column 871: promise
# Column 872: protect
# Column 873: proud
# Column 874: prove
# Column 875: pull
# Column 876: pump
# Column 877: punch
# Column 878: punk
# Column 879: pure
# Column 880: push
# Column 881: pussy
# Column 882: quarter
# Column 883: queen
# Column 884: question
# Column 885: quick
# Column 886: quiet
# Column 887: quit
# Column 888: quite
# Column 889: race
# Column 890: radio
# Column 891: rage
# Column 892: rain
# Column 893: raise
# Column 894: rap
# Column 895: rapper
# Column 896: rat
# Column 897: raw
# Column 898: reach
# Column 899: read
# Column 900: ready
# Column 901: real
# Column 902: reality
# Column 903: realize
# Column 904: really
# Column 905: really want
# Column 906: reason
# Column 907: recognize
# Column 908: record
# Column 909: red
# Column 910: refuse
# Column 911: regret
# Column 912: relax
# Column 913: release
# Column 914: remain
# Column 915: remember
# Column 916: remind
# Column 917: rent
# Column 918: repeat
# Column 919: respect
# Column 920: rest
# Column 921: return
# Column 922: rhyme
# Column 923: rhythm
# Column 924: rich
# Column 925: ride
# Column 926: ridin
# Column 927: right
# Column 928: right right
# Column 929: ring
# Column 930: rip
# Column 931: rise
# Column 932: river
# Column 933: road
# Column 934: rob
# Column 935: rock
# Column 936: rock roll
# Column 937: rockin
# Column 938: roll
# Column 939: rollin
# Column 940: roof
# Column 941: room
# Column 942: rose
# Column 943: rough
# Column 944: round
# Column 945: row
# Column 946: rule
# Column 947: run
# Column 948: run away
# Column 949: runnin
# Column 950: rush
# Column 951: sack
# Column 952: sad
# Column 953: safe
# Column 954: sail
# Column 955: sand
# Column 956: save
# Column 957: say
# Column 958: say come
# Column 959: say goodbye
# Column 960: say know
# Column 961: say like
# Column 962: say love
# Column 963: say oh
# Column 964: say say
# Column 965: say want
# Column 966: sayin
# Column 967: scar
# Column 968: scare
# Column 969: scared
# Column 970: scene
# Column 971: school
# Column 972: score
# Column 973: scratch
# Column 974: scream
# Column 975: screen
# Column 976: screw
# Column 977: sea
# Column 978: search
# Column 979: season
# Column 980: seat
# Column 981: second
# Column 982: secret
# Column 983: seed
# Column 984: seek
# Column 985: self
# Column 986: sell
# Column 987: send
# Column 988: sense
# Column 989: serve
# Column 990: set
# Column 991: set free
# Column 992: settle
# Column 993: seven
# Column 994: sex
# Column 995: sexy
# Column 996: shade
# Column 997: shadow
# Column 998: shake
# Column 999: shall
# Column 1000: shame
# Column 1001: shape
# Column 1002: share
# Column 1003: sheet
# Column 1004: shell
# Column 1005: shine
# Column 1006: ship
# Column 1007: shirt
# Column 1008: shit
# Column 1009: shit like
# Column 1010: shoe
# Column 1011: shoot
# Column 1012: shop
# Column 1013: shore
# Column 1014: short
# Column 1015: shorty
# Column 1016: shot
# Column 1017: shoulder
# Column 1018: shout
# Column 1019: shut
# Column 1020: sick
# Column 1021: sight
# Column 1022: sign
# Column 1023: silence
# Column 1024: silent
# Column 1025: silly
# Column 1026: silver
# Column 1027: simple
# Column 1028: sin
# Column 1029: sing
# Column 1030: sing song
# Column 1031: singe
# Column 1032: single
# Column 1033: sink
# Column 1034: sip
# Column 1035: sippin
# Column 1036: sister
# Column 1037: sit
# Column 1038: sittin
# Column 1039: situation
# Column 1040: size
# Column 1041: skin
# Column 1042: sky
# Column 1043: slap
# Column 1044: slave
# Column 1045: sleep
# Column 1046: slide
# Column 1047: slip
# Column 1048: slow
# Column 1049: slowly
# Column 1050: smack
# Column 1051: small
# Column 1052: smart
# Column 1053: smash
# Column 1054: smell
# Column 1055: smile
# Column 1056: smoke
# Column 1057: smokin
# Column 1058: smooth
# Column 1059: snake
# Column 1060: snow
# Column 1061: soft
# Column 1062: soldier
# Column 1063: somebody
# Column 1064: someday
# Column 1065: son
# Column 1066: song
# Column 1067: soon
# Column 1068: sorrow
# Column 1069: sorry
# Column 1070: soul
# Column 1071: sound
# Column 1072: sound like
# Column 1073: south
# Column 1074: space
# Column 1075: spark
# Column 1076: speak
# Column 1077: special
# Column 1078: speed
# Column 1079: spell
# Column 1080: spend
# Column 1081: spin
# Column 1082: spirit
# Column 1083: spit
# Column 1084: split
# Column 1085: spot
# Column 1086: spray
# Column 1087: spread
# Column 1088: spring
# Column 1089: square
# Column 1090: squeeze
# Column 1091: stack
# Column 1092: stage
# Column 1093: stain
# Column 1094: stand
# Column 1095: star
# Column 1096: stare
# Column 1097: start
# Column 1098: state
# Column 1099: station
# Column 1100: stay
# Column 1101: steady
# Column 1102: steal
# Column 1103: steel
# Column 1104: step
# Column 1105: stick
# Column 1106: stone
# Column 1107: stop
# Column 1108: store
# Column 1109: storm
# Column 1110: story
# Column 1111: straight
# Column 1112: strange
# Column 1113: stranger
# Column 1114: strap
# Column 1115: street
# Column 1116: strength
# Column 1117: stress
# Column 1118: strike
# Column 1119: string
# Column 1120: strip
# Column 1121: strong
# Column 1122: struggle
# Column 1123: stuff
# Column 1124: stupid
# Column 1125: style
# Column 1126: suck
# Column 1127: sucker
# Column 1128: suddenly
# Column 1129: suffer
# Column 1130: sugar
# Column 1131: suit
# Column 1132: summer
# Column 1133: sun
# Column 1134: sunday
# Column 1135: sunshine
# Column 1136: super
# Column 1137: suppose
# Column 1138: sure
# Column 1139: surprise
# Column 1140: surround
# Column 1141: survive
# Column 1142: swallow
# Column 1143: swear
# Column 1144: sweat
# Column 1145: sweet
# Column 1146: swim
# Column 1147: swing
# Column 1148: switch
# Column 1149: table
# Column 1150: takin
# Column 1151: talk
# Column 1152: talkin
# Column 1153: talkin bout
# Column 1154: tall
# Column 1155: tape
# Column 1156: taste
# Column 1157: teach
# Column 1158: team
# Column 1159: tear
# Column 1160: tell
# Column 1161: tell love
# Column 1162: tell tell
# Column 1163: tellin
# Column 1164: test
# Column 1165: thang
# Column 1166: thank
# Column 1167: thing
# Column 1168: thing know
# Column 1169: thing say
# Column 1170: think
# Column 1171: think know
# Column 1172: thinkin
# Column 1173: thirty
# Column 1174: thought
# Column 1175: thousand
# Column 1176: thrill
# Column 1177: throat
# Column 1178: throw
# Column 1179: thug
# Column 1180: thunder
# Column 1181: ticket
# Column 1182: tie
# Column 1183: tight
# Column 1184: til
# Column 1185: till
# Column 1186: time
# Column 1187: time come
# Column 1188: time know
# Column 1189: time make
# Column 1190: time say
# Column 1191: time time
# Column 1192: tip
# Column 1193: tired
# Column 1194: today
# Column 1195: toe
# Column 1196: tomorrow
# Column 1197: tongue
# Column 1198: tonight
# Column 1199: tooth
# Column 1200: touch
# Column 1201: tough
# Column 1202: tour
# Column 1203: town
# Column 1204: toy
# Column 1205: track
# Column 1206: trade
# Column 1207: train
# Column 1208: trap
# Column 1209: travel
# Column 1210: treat
# Column 1211: tree
# Column 1212: trick
# Column 1213: trigger
# Column 1214: trip
# Column 1215: trippin
# Column 1216: trouble
# Column 1217: truck
# Column 1218: true
# Column 1219: truly
# Column 1220: trunk
# Column 1221: trust
# Column 1222: truth
# Column 1223: try
# Column 1224: try make
# Column 1225: tryin
# Column 1226: tryna
# Column 1227: tune
# Column 1228: turn
# Column 1229: tv
# Column 1230: twice
# Column 1231: twist
# Column 1232: type
# Column 1233: ugly
# Column 1234: uh
# Column 1235: uh huh
# Column 1236: uh uh
# Column 1237: underground
# Column 1238: underneath
# Column 1239: understand
# Column 1240: unless
# Column 1241: use
# Column 1242: vein
# Column 1243: verse
# Column 1244: victim
# Column 1245: view
# Column 1246: vision
# Column 1247: voice
# Column 1248: wait
# Column 1249: waitin
# Column 1250: wake
# Column 1251: walk
# Column 1252: walk away
# Column 1253: walkin
# Column 1254: wall
# Column 1255: wanna
# Column 1256: wanna know
# Column 1257: want
# Column 1258: want know
# Column 1259: want love
# Column 1260: want want
# Column 1261: war
# Column 1262: warm
# Column 1263: wash
# Column 1264: waste
# Column 1265: waste time
# Column 1266: watch
# Column 1267: water
# Column 1268: wave
# Column 1269: way
# Column 1270: way feel
# Column 1271: way know
# Column 1272: way way
# Column 1273: weak
# Column 1274: weapon
# Column 1275: wear
# Column 1276: weather
# Column 1277: weed
# Column 1278: week
# Column 1279: weight
# Column 1280: welcome
# Column 1281: west
# Column 1282: wet
# Column 1283: wheel
# Column 1284: whip
# Column 1285: whisper
# Column 1286: white
# Column 1287: whoa
# Column 1288: whore
# Column 1289: wicked
# Column 1290: wide
# Column 1291: wife
# Column 1292: wild
# Column 1293: win
# Column 1294: wind
# Column 1295: window
# Column 1296: wine
# Column 1297: wing
# Column 1298: winter
# Column 1299: wipe
# Column 1300: wire
# Column 1301: wise
# Column 1302: wish
# Column 1303: wit
# Column 1304: witness
# Column 1305: woah
# Column 1306: woman
# Column 1307: wonder
# Column 1308: woo
# Column 1309: wood
# Column 1310: word
# Column 1311: word say
# Column 1312: work
# Column 1313: world
# Column 1314: worry
# Column 1315: worth
# Column 1316: wound
# Column 1317: wrap
# Column 1318: wreck
# Column 1319: wrist
# Column 1320: write
# Column 1321: wrong
# Column 1322: ya
# Column 1323: yall
# Column 1324: yard
# Column 1325: yea
# Column 1326: yeah
# Column 1327: yeah know
# Column 1328: yeah oh
# Column 1329: yeah yeah
# Column 1330: year
# Column 1331: yell
# Column 1332: yellow
# Column 1333: yes
# Column 1334: yesterday
# Column 1335: yo
# Column 1336: york
# Column 1337: young
# Column 1338: youth
# Column 1339: zone

# %%
lyrics_df
# Out:
#                                title   tag                        artist  \
# 0                          let it be  rock                   the beatles
# 1                          your song  rock                    elton john
# 2                           paranoid  rock                 black sabbath
# 3                     immigrant song  rock                  led zeppelin
# 4        have you ever seen the rain  rock  creedence clearwater revival
# ...                              ...   ...                           ...
# 191995  attention female perspective   pop                    andie case
# 191996                     ​nobody 😔   rap                     shinigami
# 191997                       my time   rap                        wolves
# 191998                down in flames   pop                      ella vos
# 191999                       blank 2   rap              jeffy the puppet
#
#         release year    views      features  \
# 0               1970  1481859            {}
# 1               1970  1323166            {}
# 2               1970   508767            {}
# 3               1970   494355            {}
# 4               1970   468949            {}
# ...              ...      ...           ...
# 191995          2017    34129            {}
# 191996          2017    34115  {​shinigami}
# 191997          2017    34114            {}
# 191998          2017    34113            {}
# 191999          2017    34102            {}
#
#                                                    lyrics
# 0       find time trouble mother mary come speak word ...
# 1       little bit funny feeling inside one easily hid...
# 2       finish woman cause could help mind people thin...
# 3       2 3 4 ahh ahh come land ice snow midnight sun ...
# 4       someone tell long ago calm storm know comin ti...
# ...                                                   ...
# 191995  runnin round runnin round runnin round throwin...
# 191996  take away path follow leave hopeless empty hol...
# 191997  ready play put game come prove ready afraid pu...
# 191998  slippin edge phase watchin pretend okay every ...
# 191999  jeffy puppet hey daddy smack hoe stick pee pee...
#
# [191999 rows x 7 columns]

# %%
from sklearn.decomposition import LatentDirichletAllocation

# Assuming you already have your tfidf_matrix from earlier steps
lda = LatentDirichletAllocation(n_components=20, random_state=0)
lda.fit(tfidf_matrix)

# Get the topic distribution for documents
topic_distributions = lda.transform(tfidf_matrix)

# %%
# Define the number of words to display per topic
n_top_words = 20

# Retrieve the topics and display them
for topic_idx, topic in enumerate(lda.components_):
    print("Topic #%d:" % topic_idx)
    print(" ".join([feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]]))
    print()
# Out:
# Topic #0:
# rock roll rock roll play need know easy somebody fool time make say game love come like life want way people
#
# Topic #1:
# feel good like run feel like away time know make make feel life love run away alive come feel feel look feel good inside way
#
# Topic #2:
# ooh ooh ooh alright right right right shake oh yeah baby free ready sex love night know mmm woo body wanna ah
#
# Topic #3:
# want da want want tell know want know love tell tell know want oooh girl really say want love ay wanna need oh really want love want
#
# Topic #4:
# let dance let let hold tonight bye wanna come know tight hold tight love baby night oh let know want come let time say
#
# Topic #5:
# nigga bitch fuck niggas like shit know yeah money cause ass ya man make say yo wanna gon tell come
#
# Topic #6:
# like round say come eye look head red know make night man time ride hand white leave turn black oh
#
# Topic #7:
# like yo ya cause rhyme man shit know come make rap rock say yeah mic check uh mc time let
#
# Topic #8:
# dream eye love shine day away night blue come light know sun believe time wish close star world life make
#
# Topic #9:
# sea fly burn love water river away sky like angel come heart eye light sail fall high know heaven oh
#
# Topic #10:
# love love love know heart oh say need make forever know love time way fall fall love feel want baby like day let
#
# Topic #11:
# time know say think love make try thing way heart tell feel want like cause need maybe leave hurt wrong
#
# Topic #12:
# hey hey hey say like man know look come oh make think mr good want yeah big time little tell guy
#
# Topic #13:
# home say old man little boy girl know come mama like woman good daddy love oh tell make time day
#
# Topic #14:
# baby love oh girl baby baby know come yeah way wanna want babe oh baby need lovin like make let say time
#
# Topic #15:
# god lord life die man world jesus death war come live blood know soul make time kill love power fight
#
# Topic #16:
# oh oh oh yeah la la la yeah yeah ah whoa oh yeah come uh come come know love baby ooh woah girl yeah oh like
#
# Topic #17:
# ha ha ha like music party girl yeah say know come dance let beat everybody make oh nah wanna want funky
#
# Topic #18:
# sing song come day wind rain love christmas night time sun like hear away know long light sky leave tree
#
# Topic #19:
# know know know say away walk anymore way time love come think like change say say tell thing leave oh walk away want
